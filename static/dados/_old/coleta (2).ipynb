# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df_final = pd.read_csv('SofwareDeveloperIncomeExpensesperUSACity.csv')
df_final.head(3)
# Out:
#    Unnamed: 0                              Metro  \
# 0           0                       Columbus, OH
# 1           1        Seattle-Tacoma-Bellevue, WA
# 2           2  Charlotte-Concord-Gastonia, NC-SC
#
#    Mean Software Developer Salary (adjusted)  \
# 0                                   117552.0
# 1                                   117323.0
# 2                                   114122.0
#
#    Mean Software Developer Salary (unadjusted)  \
# 0                                     108500.0
# 1                                     131167.0
# 2                                     107046.0
#
#    Mean Unadjusted Salary (all occupations)  \
# 0                                   51260.0
# 1                                   65400.0
# 2                                   51000.0
#
#    Number of Software Developer Jobs  Median Home Price           City  \
# 0                            13430.0           192000.0   Columbus, OH
# 1                            65760.0           491600.0    Seattle, WA
# 2                            12800.0           208500.0  Charlotte, NC
#
#    Cost of Living avg  Rent avg  Cost of Living Plus Rent avg  \
# 0               984.8    1421.5                        2856.5
# 1              1250.7    2528.2                        4091.5
# 2               989.9    1974.5                        3221.1
#
#    Local Purchasing Power avg
# 0                      9335.4
# 1                      8971.3
# 2                      8939.8

# %%
de_para_novos_nomes = {
    'Mean Software Developer Salary (unadjusted)'   : 'vl_salario',
    'Number of Software Developer Jobs'             : 'nr_empregos',
    'Median Home Price'                             : 'vl_moradia',
    # 'City'                                          : 'nm_cidade',
    'Cost of Living avg'                            : 'vl_custo_vida',
    'Rent avg'                                      : 'vl_aluguel',
    'Local Purchasing Power avg'                    : 'vl_poder_compra'
}
df_final.rename(columns=de_para_novos_nomes, inplace=True)
df_final.head(3)
# Out:
#    Unnamed: 0                              Metro  \
# 0           0                       Columbus, OH
# 1           1        Seattle-Tacoma-Bellevue, WA
# 2           2  Charlotte-Concord-Gastonia, NC-SC
#
#    Mean Software Developer Salary (adjusted)  vl_salario  \
# 0                                   117552.0    108500.0
# 1                                   117323.0    131167.0
# 2                                   114122.0    107046.0
#
#    Mean Unadjusted Salary (all occupations)  nr_empregos  vl_moradia  \
# 0                                   51260.0      13430.0    192000.0
# 1                                   65400.0      65760.0    491600.0
# 2                                   51000.0      12800.0    208500.0
#
#             City  vl_custo_vida  vl_aluguel  Cost of Living Plus Rent avg  \
# 0   Columbus, OH          984.8      1421.5                        2856.5
# 1    Seattle, WA         1250.7      2528.2                        4091.5
# 2  Charlotte, NC          989.9      1974.5                        3221.1
#
#    vl_poder_compra
# 0           9335.4
# 1           8971.3
# 2           8939.8

# %%
df_final.corr()
print('Notas observações:  \n\t* As variáveis com maior correlação com o salário são "nr_empregos" e "vl_moradia".\n' + 
                            '\t* As variáveis "vl_custo_vida", "vl_poder_compra" demonstraram menor correlação em relação ao salário.\n'
                            '\t* A variável "vl_aluguel" teve baixíssima correlação e apresentando-se negativa.\n')
# Out:
# <ipython-input-8-26c39ad516ce>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_final.corr()
#                                            Unnamed: 0  \
# Unnamed: 0                                   1.000000
# Mean Software Developer Salary (adjusted)   -0.969919
# vl_salario                                  -0.647816
# Mean Unadjusted Salary (all occupations)    -0.280424
# nr_empregos                                 -0.266531
# vl_moradia                                  -0.195983
# vl_custo_vida                               -0.011762
# vl_aluguel                                  -0.051200
# Cost of Living Plus Rent avg                -0.133584
# vl_poder_compra                             -0.279848
#
#                                            Mean Software Developer Salary (adjusted)  \
# Unnamed: 0                                                                 -0.969919
# Mean Software Developer Salary (adjusted)                                   1.000000
# vl_salario                                                                  0.618748
# Mean Unadjusted Salary (all occupations)                                    0.256262
# nr_empregos                                                                 0.271436
# vl_moradia                                                                  0.123461
# vl_custo_vida                                                               0.001220
# vl_aluguel                                                                  0.050742
# Cost of Living Plus Rent avg                                                0.112387
# vl_poder_compra                                                             0.317559
#
#                                            vl_salario  \
# Unnamed: 0                                  -0.647816
# Mean Software Developer Salary (adjusted)    0.618748
# vl_salario                                   1.000000
# Mean Unadjusted Salary (all occupations)     0.837704
# nr_empregos                                  0.784464
# vl_moradia                                   0.785842
# vl_custo_vida                                0.152999
# vl_aluguel                                  -0.019006
# Cost of Living Plus Rent avg                -0.010738
# vl_poder_compra                              0.349720
#
#                                            Mean Unadjusted Salary (all occupations)  \
# Unnamed: 0                                                                -0.280424
# Mean Software Developer Salary (adjusted)                                  0.256262
# vl_salario                                                                 0.837704
# Mean Unadjusted Salary (all occupations)                                   1.000000
# nr_empregos                                                                0.816883
# vl_moradia                                                                 0.835459
# vl_custo_vida                                                              0.112083
# vl_aluguel                                                                 0.003229
# Cost of Living Plus Rent avg                                              -0.123182
# vl_poder_compra                                                            0.312406
#
#                                            nr_empregos  vl_moradia  \
# Unnamed: 0                                   -0.266531   -0.195983
# Mean Software Developer Salary (adjusted)     0.271436    0.123461
# vl_salario                                    0.784464    0.785842
# Mean Unadjusted Salary (all occupations)      0.816883    0.835459
# nr_empregos                                   1.000000    0.652009
# vl_moradia                                    0.652009    1.000000
# vl_custo_vida                                 0.170448    0.126911
# vl_aluguel                                   -0.021038   -0.019267
# Cost of Living Plus Rent avg                 -0.089473   -0.063559
# vl_poder_compra                               0.339211    0.199677
#
#                                            vl_custo_vida  vl_aluguel  \
# Unnamed: 0                                     -0.011762   -0.051200
# Mean Software Developer Salary (adjusted)       0.001220    0.050742
# vl_salario                                      0.152999   -0.019006
# Mean Unadjusted Salary (all occupations)        0.112083    0.003229
# nr_empregos                                     0.170448   -0.021038
# vl_moradia                                      0.126911   -0.019267
# vl_custo_vida                                   1.000000   -0.017873
# vl_aluguel                                     -0.017873    1.000000
# Cost of Living Plus Rent avg                   -0.029944   -0.039798
# vl_poder_compra                                -0.002585   -0.009309
#
#                                            Cost of Living Plus Rent avg  \
# Unnamed: 0                                                    -0.133584
# Mean Software Developer Salary (adjusted)                      0.112387
# vl_salario                                                    -0.010738
# Mean Unadjusted Salary (all occupations)                      -0.123182
# nr_empregos                                                   -0.089473
# vl_moradia                                                    -0.063559
# vl_custo_vida                                                 -0.029944
# vl_aluguel                                                    -0.039798
# Cost of Living Plus Rent avg                                   1.000000
# vl_poder_compra                                               -0.206616
#
#                                            vl_poder_compra
# Unnamed: 0                                       -0.279848
# Mean Software Developer Salary (adjusted)         0.317559
# vl_salario                                        0.349720
# Mean Unadjusted Salary (all occupations)          0.312406
# nr_empregos                                       0.339211
# vl_moradia                                        0.199677
# vl_custo_vida                                    -0.002585
# vl_aluguel                                       -0.009309
# Cost of Living Plus Rent avg                     -0.206616
# vl_poder_compra                                   1.000000
# Notas observações:
# 	* As variáveis com maior correlação com o salário são "nr_empregos" e "vl_moradia".
# 	* As variáveis "vl_custo_vida", "vl_poder_compra" demonstraram menor correlação em relação ao salário.
# 	* A variável "vl_aluguel" teve baixíssima correlação e apresentando-se negativa.

# %%
print('Tabela descritiva das variáveis:')
df_final.describe().round(2)
# Out:
# Tabela descritiva das variáveis:
#        Unnamed: 0  Mean Software Developer Salary (adjusted)  vl_salario  \
# count       77.00                                      77.00       77.00
# mean        38.00                                  100832.97   101866.21
# std         22.37                                    8064.30    13926.64
# min          0.00                                   72811.00    80314.00
# 25%         19.00                                   95308.00    91976.00
# 50%         38.00                                  101256.00   100614.00
# 75%         57.00                                  107170.00   109503.00
# max         76.00                                  117552.00   142101.00
#
#        Mean Unadjusted Salary (all occupations)  nr_empregos  vl_moradia  \
# count                                     77.00        77.00       77.00
# mean                                   53277.27     19098.57   312701.30
# std                                     7813.34     23858.15   222743.31
# min                                    44500.00      1120.00   124100.00
# 25%                                    48240.00      3170.00   178400.00
# 50%                                    51050.00      8770.00   243700.00
# 75%                                    56160.00     21160.00   366000.00
# max                                    80480.00     98650.00  1193600.00
#
#        vl_custo_vida  vl_aluguel  Cost of Living Plus Rent avg  \
# count          77.00       77.00                         77.00
# mean         1414.06     3280.43                       6506.99
# std          2369.54     9118.81                      20325.07
# min           832.50      879.30                       2241.40
# 25%           957.30     1340.50                       2810.80
# 50%           995.00     1625.80                       2999.90
# 75%          1086.00     2171.90                       3446.90
# max         15809.20    58597.60                     130097.80
#
#        vl_poder_compra
# count            77.00
# mean           7421.23
# std            1327.44
# min            4840.10
# 25%            6464.20
# 50%            7499.00
# 75%            8153.10
# max           10673.70

# %%
#Histograma das variáveis
df_final[['nr_empregos', 'vl_moradia', 'vl_salario', 'vl_custo_vida', 'vl_aluguel', 'vl_poder_compra']].hist(figsize=(15,9), bins=50);
print('Aqui podemos visualizar melhor os OUTLIERS.');
# Out:
# Aqui podemos visualizar melhor os OUTLIERS.

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df_final.corr(), annot = True, cmap= "RdYlGn");
plt.title('Correlação',size=15);
# Out:
# <ipython-input-11-accfa6959e0a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_final.corr(), annot = True, cmap= "RdYlGn");
